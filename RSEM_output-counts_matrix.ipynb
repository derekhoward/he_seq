# %%
from pathlib import Path
import pandas as pd

# %%
results_path = Path('/external/rprshnas01/netdata_kcni/stlab/he_human_processed/RSEM_results')

# %%
rsem_result_dirs = list(results_path.glob('*'))

# %%
len(rsem_result_dirs)
# Out:
# 102

# %%
sample_dfs = [] 
for i, result in enumerate(rsem_result_dirs):
    sample_counts = result.glob('.genes.results')
    counts_path = list(sample_counts)
    
    if len(counts_path) > 0:
        #print(f'SampleID: {result.stem}, {counts_path}')
        try:
            df = pd.read_csv(counts_path[0], sep='\t')
            df = df.loc[:, ['gene_id', 'expected_count']]
            df.rename(columns={"expected_count": result.stem}, inplace=True)
            sample_dfs.append(df.set_index('gene_id'))
        except pd.io.common.EmptyDataError:
            print(f'EmptyDataError for file: {counts_path[0]}')
    else:
        print(result.stem)
    #print('**'*50)

# %%
concat = pd.concat(sample_dfs, axis=1)

# %%
# use this table to convert ENSG to gene_symbols
convert_genes = pd.read_table('../ENSG_to_gene_name.tsv', sep='\t', header=None, names=['gene_id', 'gene_symbol'])

# %%
convert_genes.head()
# Out:
#            gene_id gene_symbol
# 0  ENSG00000000003      TSPAN6
# 1  ENSG00000000005        TNMD
# 2  ENSG00000000419        DPM1
# 3  ENSG00000000457       SCYL3
# 4  ENSG00000000460    C1orf112

# %%
counts_matrix = concat.merge(convert_genes, left_index=True, right_on=['gene_id']).set_index('gene_symbol').drop('gene_id', axis=1)

# %%
counts_matrix
# Out:
#              SRR2815999_RNA-Seq_of_Human_PFC_section_DS1-Human3-S12  \
# gene_symbol
# TSPAN6                                                   58.00
# TNMD                                                      0.00
# DPM1                                                    145.00
# SCYL3                                                    60.51
# C1orf112                                                 12.49
# ...                                                        ...
# AC064824.1                                               26.08
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                6.84
# AL353795.4                                                0.00
#
#              SRR2815975_RNA-Seq_of_Human_PFC_section_DS1-Human2-S6  \
# gene_symbol
# TSPAN6                                                   68.00
# TNMD                                                      2.00
# DPM1                                                    216.00
# SCYL3                                                   112.42
# C1orf112                                                 12.58
# ...                                                        ...
# AC064824.1                                               22.67
# AL136225.2                                                2.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2815970_RNA-Seq_of_Human_PFC_section_DS1-Human2-S1  \
# gene_symbol
# TSPAN6                                                  314.00
# TNMD                                                      2.00
# DPM1                                                     98.00
# SCYL3                                                   113.96
# C1orf112                                                 39.04
# ...                                                        ...
# AC064824.1                                               20.37
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816098_RNA-Seq_of_Human_PFC_section_DS2-HumanA-Rep1-S6  \
# gene_symbol
# TSPAN6                                                   43.00
# TNMD                                                      3.00
# DPM1                                                    166.00
# SCYL3                                                   111.44
# C1orf112                                                 21.56
# ...                                                        ...
# AC064824.1                                               24.77
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.08
# AL353795.4                                                0.00
#
#              SRR2815998_RNA-Seq_of_Human_PFC_section_DS1-Human3-S11  \
# gene_symbol
# TSPAN6                                                    79.0
# TNMD                                                       2.0
# DPM1                                                     205.0
# SCYL3                                                    109.4
# C1orf112                                                   7.6
# ...                                                        ...
# AC064824.1                                                21.8
# AL136225.2                                                 0.0
# AC004636.1                                                 0.0
# AC007687.1                                                 0.0
# AL353795.4                                                 0.0
#
#              SRR2815958_RNA-Seq_of_Human_PFC_section_DS1-Human1-S7  \
# gene_symbol
# TSPAN6                                                   47.00
# TNMD                                                      1.00
# DPM1                                                    189.00
# SCYL3                                                   125.11
# C1orf112                                                 10.89
# ...                                                        ...
# AC064824.1                                               31.16
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                               10.87
# AL353795.4                                                0.00
#
#              SRR2815980_RNA-Seq_of_Human_PFC_section_DS1-Human2-S11  \
# gene_symbol
# TSPAN6                                                   57.00
# TNMD                                                      2.00
# DPM1                                                    150.00
# SCYL3                                                    75.88
# C1orf112                                                  9.12
# ...                                                        ...
# AC064824.1                                               27.83
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816122_RNA-Seq_of_Human_PFC_section_DS2-HumanB-S10  \
# gene_symbol
# TSPAN6                                                   63.00
# TNMD                                                      0.00
# DPM1                                                     85.00
# SCYL3                                                    71.65
# C1orf112                                                 33.35
# ...                                                        ...
# AC064824.1                                               25.44
# AL136225.2                                                1.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816095_RNA-Seq_of_Human_PFC_section_DS2-HumanA-Rep1-S3  \
# gene_symbol
# TSPAN6                                                   82.00
# TNMD                                                      2.00
# DPM1                                                    236.00
# SCYL3                                                   198.27
# C1orf112                                                 48.73
# ...                                                        ...
# AC064824.1                                               29.89
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816110_RNA-Seq_of_Human_PFC_section_DS2-HumanA-Rep2-S8  ...  \
# gene_symbol                                                              ...
# TSPAN6                                                   73.00           ...
# TNMD                                                      1.00           ...
# DPM1                                                    162.00           ...
# SCYL3                                                   117.78           ...
# C1orf112                                                 34.22           ...
# ...                                                        ...           ...
# AC064824.1                                               26.48           ...
# AL136225.2                                                0.00           ...
# AC004636.1                                                0.00           ...
# AC007687.1                                                0.00           ...
# AL353795.4                                                0.00           ...
#
#              SRR2815981_RNA-Seq_of_Human_PFC_section_DS1-Human2-S12  \
# gene_symbol
# TSPAN6                                                   58.00
# TNMD                                                      0.00
# DPM1                                                    122.00
# SCYL3                                                    98.30
# C1orf112                                                 11.70
# ...                                                        ...
# AC064824.1                                               23.06
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816020_RNA-Seq_of_Human_PFC_section_DS1-Human4-S15  \
# gene_symbol
# TSPAN6                                                   52.00
# TNMD                                                      1.00
# DPM1                                                    129.00
# SCYL3                                                   114.76
# C1orf112                                                 27.24
# ...                                                        ...
# AC064824.1                                               31.90
# AL136225.2                                                4.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816004_RNA-Seq_of_Human_PFC_section_DS1-Human3-S17  \
# gene_symbol
# TSPAN6                                                   43.00
# TNMD                                                      0.00
# DPM1                                                    132.00
# SCYL3                                                    94.52
# C1orf112                                                 32.48
# ...                                                        ...
# AC064824.1                                               61.55
# AL136225.2                                                3.00
# AC004636.1                                                0.00
# AC007687.1                                                0.19
# AL353795.4                                                0.00
#
#              SRR2816016_RNA-Seq_of_Human_PFC_section_DS1-Human4-S11  \
# gene_symbol
# TSPAN6                                                   52.00
# TNMD                                                      0.00
# DPM1                                                    153.00
# SCYL3                                                    94.85
# C1orf112                                                 10.15
# ...                                                        ...
# AC064824.1                                               31.55
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2816001_RNA-Seq_of_Human_PFC_section_DS1-Human3-S14  \
# gene_symbol
# TSPAN6                                                   68.00
# TNMD                                                      0.00
# DPM1                                                    136.00
# SCYL3                                                    90.49
# C1orf112                                                 18.51
# ...                                                        ...
# AC064824.1                                               47.92
# AL136225.2                                                1.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2815984_RNA-Seq_of_Human_PFC_section_DS1-Human2-S15  \
# gene_symbol
# TSPAN6                                                    0.00
# TNMD                                                      0.00
# DPM1                                                      0.00
# SCYL3                                                    77.78
# C1orf112                                                 20.22
# ...                                                        ...
# AC064824.1                                                0.00
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2815994_RNA-Seq_of_Human_PFC_section_DS1-Human3-S7  \
# gene_symbol
# TSPAN6                                                   66.00
# TNMD                                                      1.00
# DPM1                                                    168.00
# SCYL3                                                    99.51
# C1orf112                                                  6.49
# ...                                                        ...
# AC064824.1                                                4.82
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.11
# AL353795.4                                                0.00
#
#              SRR2815991_RNA-Seq_of_Human_PFC_section_DS1-Human3-S4  \
# gene_symbol
# TSPAN6                                                   68.00
# TNMD                                                      0.00
# DPM1                                                    169.00
# SCYL3                                                    93.43
# C1orf112                                                 11.57
# ...                                                        ...
# AC064824.1                                               20.00
# AL136225.2                                                1.00
# AC004636.1                                                0.00
# AC007687.1                                                0.56
# AL353795.4                                                0.00
#
#              SRR2816094_RNA-Seq_of_Human_PFC_section_DS2-HumanA-Rep1-S2  \
# gene_symbol
# TSPAN6                                                   47.00
# TNMD                                                      1.00
# DPM1                                                    127.00
# SCYL3                                                    95.58
# C1orf112                                                 23.42
# ...                                                        ...
# AC064824.1                                               13.85
# AL136225.2                                                1.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
#              SRR2815985_RNA-Seq_of_Human_PFC_section_DS1-Human2-S16
# gene_symbol
# TSPAN6                                                   92.00
# TNMD                                                      0.00
# DPM1                                                    147.00
# SCYL3                                                    76.90
# C1orf112                                                 17.10
# ...                                                        ...
# AC064824.1                                               20.69
# AL136225.2                                                0.00
# AC004636.1                                                0.00
# AC007687.1                                                0.00
# AL353795.4                                                0.00
#
# [60666 rows x 102 columns]

# %%
counts_matrix.to_csv('results/102_counts_matrix.csv')
